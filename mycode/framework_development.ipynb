# %% [markdown]
# # 框架开发
#
# > 从编写一次性的脚本到使用一个成熟的框架，是软件工程领域一次重要的思维跃迁
#
# > 一个框架的本质，是提供一套经过验证的“规范”. 让我们在构建新的智能体时，能够专注于其独特的业务逻辑，而非通用的底层实现。

# %%
# %cd ../

from dotenv import load_dotenv
load_dotenv()
# Out:
# /Users/yqz/project/hello-agents
# True

# %% [markdown]
# ## Autogen

# %% [markdown]
# ### 设计哲学
#
# 以对话驱动协作
#
# 即将复杂的任务解决流程, 映射为不同角色智能体之间的一系列自动化对话
#
# ![image.png](attachment:image.png)
